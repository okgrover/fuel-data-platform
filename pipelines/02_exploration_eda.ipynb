# %% [markdown]
# # 02: Exploration and EDA
#
# This notebook loads the cleaned processed CSV outputs and performs exploratory data analysis (EDA) to understand the data structure, distributions, and quality.

# %%
import pandas as pd
import os

processed_dir = os.path.join('..', 'data', 'processed')
source1_path = os.path.join('..', 'data', 'raw', 'source1_global.csv')
source2_path = os.path.join(processed_dir, 'source2_uk_clean.csv')
source3_path = os.path.join(processed_dir, 'source3_uk_clean.csv')

source1 = pd.read_csv(source1_path)
source2 = pd.read_csv(source2_path)
source3 = pd.read_csv(source3_path)

print('Loaded:', source1_path, '->', source1.shape)
print('Loaded:', source2_path, '->', source2.shape)
print('Loaded:', source3_path, '->', source3.shape)
# Out:
# Loaded: ../data/raw/source1_global.csv -> (675, 2)
# Loaded: ../data/processed/source2_uk_clean.csv -> (447, 15)
# Loaded: ../data/processed/source3_uk_clean.csv -> (326, 33)

# %% [markdown]
# ## 2.1 Basic shape and preview

# %%
print('Source 2 shape:', source2.shape)
print(source2.head(10).to_string(index=False))

print('\nSource 3 shape:', source3.shape)
print(source3.head(10).to_string(index=False))

print('\nSource 1 shape:', source1.shape)
print(source1.head(10).to_string(index=False))
# Out:
# Source 2 shape: (447, 15)
#  Year     Month  Motor spirit:\n4 star / LRP\n(Pence per litre)\n[Note 1]  Motor spirit: Super unleaded \n(Pence per litre)\n[Note 1]  Motor spirit: Premium unleaded / ULSP\n(Pence per litre)\n[Note 1, 2]  Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1, 2]  Standard grade burning oil\n(Pence per litre)\n[Note 1]  Gas oil\n(Pence per litre)\n[Note 1, 3]  Crude oil acquired by refineries\n2025 = 100\n[Note 4]  ULSP to ULSD Differential (Pence per litre)  Historic Indices: Crude oil acquired by refineries\n2010 = 100  Historic Indices: Crude oil acquired by refineries\n2005 = 100  Historic Indices: Crude oil acquired by refineries\n2000 = 100 Historic Indices: Crude oil acquired by refineries\n1995 = 100        Month / Year
#  1989   January                                                     37.14                                                         NaN                                                                  36.02                                                34.17                                                    11.41                                    11.15                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-01-01 00:00:00
#  1989  February                                                     38.30                                                         NaN                                                                  36.88                                                35.03                                                    10.83                                    10.49                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-02-01 00:00:00
#  1989     March                                                     38.85                                                         NaN                                                                  37.30                                                35.09                                                    11.40                                    10.90                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-03-01 00:00:00
#  1989     April                                                     41.14                                                         NaN                                                                  39.09                                                36.08                                                    11.45                                    10.83                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-04-01 00:00:00
#  1989       May                                                     42.83                                                         NaN                                                                  40.81                                                36.06                                                    11.41                                    10.81                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-05-01 00:00:00
#  1989      June                                                     42.70                                                         NaN                                                                  40.74                                                35.93                                                    11.48                                    11.26                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-06-01 00:00:00
#  1989      July                                                     41.49                                                         NaN                                                                  39.26                                                35.87                                                    11.00                                    10.91                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-07-01 00:00:00
#  1989    August                                                     39.92                                                         NaN                                                                  37.40                                                35.70                                                    11.48                                    11.19                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989-08-01 00:00:00
#  1989 September                                                     40.79                                                         NaN                                                                  38.19                                                36.00                                                    12.33                                    11.89                                                     NaN                                          NaN                                                             NaN                                                             NaN                                                             NaN                                                            NaN 1989
# ## 2.2 Column and type summary

# %%
print('Source 2 columns and dtypes:')
print(source2.dtypes)
print('\nSource 3 columns and dtypes:')
print(source3.dtypes)
print('\nSource 1 columns and dtypes:')
print(source1.dtypes)
# Out:
# Source 2 columns and dtypes:
# Year                                                                       int64
# Month                                                                        str
# Motor spirit:\n4 star / LRP\n(Pence per litre)\n[Note 1]                 float64
# Motor spirit: Super unleaded \n(Pence per litre)\n[Note 1]               float64
# Motor spirit: Premium unleaded / ULSP\n(Pence per litre)\n[Note 1, 2]    float64
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1, 2]                      float64
# Standard grade burning oil\n(Pence per litre)\n[Note 1]                  float64
# Gas oil\n(Pence per litre)\n[Note 1, 3]                                  float64
# Crude oil acquired by refineries\n2025 = 100\n[Note 4]                   float64
# ULSP to ULSD Differential (Pence per litre)                              float64
# Historic Indices: Crude oil acquired by refineries\n2010 = 100           float64
# Historic Indices: Crude oil acquired by refineries\n2005 = 100           float64
# Historic Indices: Crude oil acquired by refineries\n2000 = 100           float64
# Historic Indices: Crude oil acquired by refineries\n1995 = 100               str
# Month / Year                                                                 str
# dtype: object
#
# Source 3 columns and dtypes:
# Year                                int64
# Month                                 str
# Day in month of price snapshot        str
# Austria                           float64
# Belgium                           float64
# Denmark                           float64
# Finland                           float64
# France                            float64
# Germany                           float64
# Greece                            float64
# Ireland                           float64
# Italy                             float64
# Luxembourg                        float64
# Netherlands                       float64
# Portugal                          float64
# Spain                             float64
# Sweden                            float64
# United Kingdom [Note 1]           float64
# Bulgaria                          float64
# Croatia                           float64
# Cyprus                            float64
# Czechia                           float64
# Estonia                           float64
# Hungary                           float64
# Latvia                            float64
# Lithuania                         float64
# Malta                             float64
# Poland                            float64
# Romania                           float64
# Slovakia                          float64
# Slovenia                          float64
# UK Rank in EU14 plus UK             int64
# UK Rank in EU27 plus UK           float64
# dtype: object
#
# Source 1 columns and dtypes:
# Date                   str
# Crude_Oil_Price    float64
# dtype: object

# %% [markdown]
# ## 2.3 Missing values and basic statistics

# %%
print('Source 2 missing values:')
print(source2.isna().sum().sort_values(ascending=False).head(20))
print('\nSource 3 missing values:')
print(source3.isna().sum().sort_values(ascending=False).head(20))
print('\nSource 1 missing values:')
print(source1.isna().sum().sort_values(ascending=False).head(20))

print('\nSource 2 numeric summary:')
print(source2.describe(include='all').transpose())
print('\nSource 3 numeric summary:')
print(source3.describe(include='all').transpose())
print('\nSource 1 numeric summary:')
print(source1.describe(include='all').transpose())
# Out:
# Source 2 missing values:
# Historic Indices: Crude oil acquired by refineries\n1995 = 100           294
# Motor spirit:\n4 star / LRP\n(Pence per litre)\n[Note 1]                 247
# Historic Indices: Crude oil acquired by refineries\n2000 = 100           218
# Historic Indices: Crude oil acquired by refineries\n2005 = 100           170
# Crude oil acquired by refineries\n2025 = 100\n[Note 4]                   169
# Historic Indices: Crude oil acquired by refineries\n2010 = 100            86
# Motor spirit: Super unleaded \n(Pence per litre)\n[Note 1]                24
# ULSP to ULSD Differential (Pence per litre)                               24
# Standard grade burning oil\n(Pence per litre)\n[Note 1]                    0
# Motor spirit: Premium unleaded / ULSP\n(Pence per litre)\n[Note 1, 2]      0
# Month                                                                      0
# Year                                                                       0
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1, 2]                        0
# Gas oil\n(Pence per litre)\n[Note 1, 3]                                    0
# Month / Year                                                               0
# dtype: int64
#
# Source 3 missing values:
# Croatia                           174
# Romania                           108
# Bulgaria                          108
# Cyprus                             65
# Czechia                            65
# Poland                             65
# Latvia                             65
# Slovenia                           65
# UK Rank in EU27 plus UK            65
# Lithuania                          65
# Malta                              65
# Estonia                            65
# Hungary                            65
# Slovakia                           65
# Day in month of price snapshot     64
# Year                                0
# Month                               0
# Sweden                              0
# Spain                               0
# Portugal                            0
# dtype: int64
#
# Source 1 missing values:
# Date               0
# Crude_Oil_Price    0
# dtype: int64
#
# Source 2 numeric summary:
#                                                     count unique  \
# Year                                                447.0    NaN
# Month                                                 447     12
# Motor spirit:\n4 star / LRP\n(Pence per litre)\...  200.0    NaN
# Motor spirit: Super unleaded \n(Pence per litre...  423.0    NaN
# Motor spirit: Premium unleaded / ULSP\n(Pence p...  447.0    NaN
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1...  447.0    NaN
# Standard grade burning oil\n(Pence per litre)\n...  447.0    NaN
# Gas oil\n(Pence per litre)\n[Note 1, 3]             447.0    NaN
# Crude oil acquired by refineries\n2025 = 100\n[...  278.0    NaN
# ULSP to ULSD Differential (Pence per litre)         423.0    NaN
# Historic Indices: Crude oil acquired by refiner...  361.0    NaN
# Historic Indices: Crude oil acquired by refiner...  277.0    NaN
# Historic Indices: Crude oil acquired by refiner...  229.0    NaN
# Historic Indices: Crude oil acquired by refiner...    153    150
# Month / Year                                          447    447
#
#                                                                     top freq  \
# Year                                                                NaN  NaN
# Month                                                           January   38
# Motor spirit:\n4 star / LRP\n(Pence per litre)\...                  NaN  NaN
# Motor spirit: Super unleaded \n(Pence per litre...                  NaN  NaN
# Motor spirit: Premium unleaded / ULSP\n(Pence p...                  NaN  NaN
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1...                  NaN  NaN
# Standard grade burning oil\n(Pence per litre)\n...                  NaN  NaN
# Gas oil\n(Pence per litre)\n[Note 1, 3]                             NaN  NaN
# Crude oil acquired by refineries\n2025 = 100\n[...                  NaN  NaN
# ULSP to ULSD Differential (Pence per litre)                         NaN  NaN
# Historic Indices: Crude oil acquired by refiner...                  NaN  NaN
# Historic Indices: Crude oil acquired by refiner...                  NaN  NaN
# Historic Indices: Crude oil acquired by refiner...                  NaN  NaN
# Historic Indices: Crude oil acquired by refiner...                99.89    2
# Month / Year                                        1989-01-01 00:00:00    1
#
#                                                            mean        std  \
# Year                                                2007.127517  10.765721
# Month                                                       NaN        NaN
# Motor spirit:\n4 star / LRP\n(Pence per litre)\...      65.8246  14.965835
# Motor spirit: Super unleaded \n(Pence per litre...   106.589478  35.529817
# Motor spirit: Premium unleaded / ULSP\n(Pence p...    95.200255  35.065475
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1...    98.669118  38.147335
# Standard grade burning oil\n(Pence per litre)\n...    33.371372  19.322303
# Gas oil\n(Pence per litre)\n[Note 1, 3]               40.081804  25.288216
# Crude oil acquired by refineries\n2025 = 100\n[...    90.924369  33.664559
# ULSP to ULSD Differential (Pence per litre)            3.769389   4.061883
# Historic Indices: Crude oil acquired by refiner...    78.663263  42.231499
# Historic Indices: Crude oil acquired by refiner...    95.113557  71.585146
# Historic Indices: Crude oil acquired by refiner...   107.009205   67.40294
# Historic Indices: Crude oil acquired by refiner...          NaN        NaN
# Month / Year                                                NaN        NaN
#
#                                                           min        25%  \
# Year                                                   1989.0     1998.0
# Month                                                     NaN        NaN
# Motor spirit:\n4 star / LRP\n(Pence per litre)\...      37.14    52.5625
# Motor spirit: Super unleaded \n(Pence per litre...      42.91      80.01
# Motor spirit: Premium unleaded / ULSP\n(Pence p...      36.02      64.14
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1...      34.17      64.62
# Standard grade burning oil\n(Pence per litre)\n...       9.89       14.7
# Gas oil\n(Pence per litre)\n[Note 1, 3]                 10.49      15.41
# Crude oil acquired by refineries\n2025 = 100\n[...  29.047782  64.431547
# ULSP to ULSD Differential (Pence per litre)              -3.0      0.995
# Historic Indices: Crude oil acquired by refiner...   11.53091  37.043386
# Historic Indices: Crude oil acquired by refiner...  20.234816  38.747494
# Historic Indices: Crude oil acquired by refiner...   31.73157  58.483745
# Historic Indices: Crude oil acquired by refiner...        NaN        NaN
# Month / Year                                              NaN        NaN
#
#                                                           50%         75%  \
# Year                                                   2007.0      2016.0
# Month                                                     NaN         NaN
# Motor spirit:\n4 star / LRP\n(Pence per litre)\...      65.45       79.78
# Motor spirit: Super unleaded \n(Pence per litre...     107.97  137.855648
# Motor spirit: Premium unleaded / ULSP\n(Pence p...      95.05  127.455079
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1...      98.68  132.284018
# Standard grade burning oil\n(Pence per litre)\n...      31.56     48.4665
# Gas oil\n(Pence per litre)\n[Note 1, 3]             38.835974   60.394986
# Crude oil acquired by refineries\n2025 = 100\n[...   92.35642  119.604466
# ULSP to ULSD Differential (Pence per litre)           2.93646    5.425973
# Historic Indices: Crude oil acquired by refiner...  76.364832  113.860377
# Historic Indices: Crude oil acquired by refiner...  59.486801  133.782623
# Historic Indices: Crude oil acquired by refiner...  82.926961       141.5
# Historic Indices: Crude oil acquired by refiner...        NaN         NaN
# Month / Year                                              NaN         NaN
#
#                                                            max
# Year                                                    2026.0
# Month                                                      NaN
# Motor spirit:\n4 star / LRP\n(Pence per litre)\...       91.99
# Motor spirit: Super unleaded \n(Pence per litre...  199.401024
# Motor spirit: Premium unleaded / ULSP\n(Pence p...  188.790773
# Derv: Diesel / ULSD\n(Pence per litre)\n[Note 1...  197.377686
# Standard grade burning oil\n(Pence per litre)\n...     104.051
# Gas oil\n(Pence per litre)\n[Note 1, 3]              128.06669
# Crude oil acquired by refineries\n2025 = 100\n[...  189.216286
# ULSP to ULSD Differential (Pence per litre)          24.328269
# Historic Indices: Crude oil acquired by refiner...  196.651038
# Historic Indices: Crude oil acquired by refiner...  270.969044
# Historic Indices: Crude oil acquired by refiner...       356.2
# Historic Indices: Crude oil acquired by refiner...         NaN
# Month / Year                                               NaN
#
# Source 3 numeric summary:
#                                 count unique                  top freq  \
# Year                            326.0    NaN                  NaN  NaN
# Month                             326    326  1999-01-01 00:00:00    1
# Day in month of price snapshot    262     18                 14th   37
# Austria                         326.0    NaN                  NaN  NaN
# Belgium                         326.0    NaN                  NaN  NaN
# Denmark                         326.0    NaN                  NaN  NaN
# UK Rank in EU27 plus UK            5.97318   5.907887        1.0        2.0
#
#                                       50%        75%         max
# Year                               2012.0     2019.0      2026.0
# Month                                 NaN        NaN         NaN
# Day in month of price snapshot        NaN        NaN         NaN
# Austria                            41.355      52.73      104.41
# Belgium                            42.595    56.3925      110.28
# Denmark                             49.25    62.0825       117.0
# Finland                              44.1      55.92      114.96
# France                               41.8    53.9325       93.01
# Germany                            41.925    55.8725      115.77
# Greece                             43.915     55.875       105.2
# Ireland                            42.685     55.645      109.56
# Italy                              44.885      57.47      100.57
# Luxembourg                         44.535      56.18       106.6
# Netherlands                         43.84    56.9025      111.42
# Portugal                           45.515     57.415       111.5
# Spain                               45.47      58.36      109.52
# Sweden                               42.5    55.2225      113.05
# United Kingdom [Note 1]         39.049834  52.042836  104.375644
# Bulgaria                            49.69       58.4       89.99
# Croatia                            51.915    58.3675       90.63
# Cyprus                               48.6      59.99       97.21
# Czechia                              46.2      55.11       96.35
# Estonia                              48.1      55.69      103.16
# Hungary                             46.87      59.33       88.18
# Latvia                              47.04      57.38      103.96
# Lithuania                           47.23      56.85      106.22
# Malta                               50.06      53.85       67.44
# Poland                              46.15      56.75      106.95
# Romania                             50.65      57.39       91.59
# Slovakia                            46.96      56.72       90.02
# Slovenia                            44.38      53.99       89.86
# UK Rank in EU14 plus UK               2.0        4.0        15.0
# UK Rank in EU27 plus UK               4.0        8.0        28.0
#
# Source 1 numeric summary:
#                  count unique         top freq      mean        std   min  \
# Date               675    675  1970-01-01    1       NaN        NaN   NaN
# Crude_Oil_Price  675.0    NaN         NaN  NaN  39.80404  30.611456  1.21
#
#                        25%        50%        75%         max
# Date                   NaN        NaN        NaN         NaN
# Crude_Oil_Price  16.533333  29.113333  61.246667  132.825184

# %% [markdown]
# ## 2.4 Visualizations
#
# Plot key trends and distributions for better understanding.

# %%
import matplotlib.pyplot as plt

# Source 1: Crude oil price over time
plt.figure(figsize=(10, 5))
plt.plot(pd.to_datetime(source1['Date']), source1['Crude_Oil_Price'], label='Crude Oil Price (USD)')
plt.title('Source 1: Crude Oil Price Trend')
plt.xlabel('Date')
plt.ylabel('Price (USD per barrel)')
plt.legend()
plt.show()

# Source 2: Sample fuel prices (first few columns)
price_cols = [col for col in source2.columns if 'Pence' in col][:3]  # First 3 price columns
plt.figure(figsize=(10, 5))
for col in price_cols:
    plt.plot(source2.index, pd.to_numeric(source2[col], errors='coerce'), label=col[:30] + '...')
plt.title('Source 2: Fuel Price Trends (Sample)')
plt.xlabel('Index')
plt.ylabel('Price (Pence per Litre)')
plt.legend()
plt.show()

# Source 3: Similar, but since it's EU prices, plot a few countries
eu_cols = [col for col in source3.columns if col not in ['Year', 'Month', 'Day in month of price snapshot']][:3]
plt.figure(figsize=(10, 5))
for col in eu_cols:
    plt.plot(source3.index, pd.to_numeric(source3[col], errors='coerce'), label=col)
plt.title('Source 3: EU Fuel Prices (Sample)')
plt.xlabel('Index')
plt.ylabel('Price (GBP per Litre)')
plt.legend()
plt.show()
